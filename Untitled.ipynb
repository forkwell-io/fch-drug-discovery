# %%
import rdkit

# %%
from rdkit.Chem import Draw

# %%
from rdkit.Chem import rdFMCS

# %%
help(rdkit.Chem.Draw)
# Out:
# Help on package rdkit.Chem.Draw in rdkit.Chem:
#
# NAME
#     rdkit.Chem.Draw
#
# DESCRIPTION
#     # Copyright (C) 2006-2019 Greg Landrum
#     #  All Rights Reserved
#     #
#     #  This file is part of the RDKit.
#     #  The contents are covered by the terms of the BSD license
#     #  which is included in the file license.txt, found at the root
#     #  of the RDKit source tree.
#     #
#
# PACKAGE CONTENTS
#     IPythonConsole
#     MolDrawing
#     SimilarityMaps
#     aggCanvas
#     cairoCanvas
#     canvasbase
#     mplCanvas
#     qtCanvas
#     rdMolDraw2D
#     spingCanvas
#
# CLASSES
#     builtins.tuple(builtins.object)
#         FingerprintEnv
#
#     class FingerprintEnv(builtins.tuple)
#      |  FingerprintEnv(submol, highlightAtoms, atomColors, highlightBonds, bondColors, highlightRadii)
#      |
#      |  Method resolution order:
#      |      FingerprintEnv
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Methods defined here:
# ...
